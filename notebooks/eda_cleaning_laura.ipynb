# %%
import pandas as pd
import numpy as np

# %% [markdown]
# loading of all 6 data sets

# %%
datasets = {}

# %%
datasets['bradenton'] = pd.read_csv('../data/bradentonFL_tempData.csv')
datasets['fl_cyanotoxins'] = pd.read_csv('../data/florida_cyanotoxins_2015-01-01_to_2026-06-17.csv')
datasets['habsos'] = pd.read_csv('../data/habsos_cellcounts.csv')
datasets['motemarine'] = pd.read_csv('../data/MoteMarine_BottomTemp.csv')
datasets['nutrients_fl']=pd.read_csv('../data/NutrientsFL_2006_2025.csv')
datasets['sarasota_wind_temp'] = pd.read_csv('../data/Sarasota_Wind&Temp.csv')
# Out:
# /var/folders/wg/kbz7sq913gsd0mwb6q3xhvj80000gn/T/ipykernel_57185/2560084173.py:2: DtypeWarning: Columns (0: ResultAnalyticalMethod_Identifi) have mixed types. Specify dtype option on import or set low_memory=False.
#   datasets['fl_cyanotoxins'] = pd.read_csv('../data/florida_cyanotoxins_2015-01-01_to_2026-06-17.csv')
# /var/folders/wg/kbz7sq913gsd0mwb6q3xhvj80000gn/T/ipykernel_57185/2560084173.py:3: DtypeWarning: Columns (0: WIND_SPEED_UNIT) have mixed types. Specify dtype option on import or set low_memory=False.
#   datasets['habsos'] = pd.read_csv('../data/habsos_cellcounts.csv')
# /var/folders/wg/kbz7sq913gsd0mwb6q3xhvj80000gn/T/ipykernel_57185/2560084173.py:6: DtypeWarning: Columns (0: z, 1: air_pressure_at_mean_sea_level, 2: dew_point_temperature, 3: air_temperature, 4: visibility_in_air, 5: wind_speed_of_gust, 6: wind_speed, 7: wind_from_direction) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
datasets['bradenton'].shape
# Out:
# (4018, 8)

# %%
datasets['bradenton'].columns
# Out:
# Index(['COOPID', ' YEAR', ' MONTH', ' DAY', ' PRECIPITATION', ' MAX TEMP',
#        ' MIN TEMP', ' MEAN TEMP'],
#       dtype='str')
